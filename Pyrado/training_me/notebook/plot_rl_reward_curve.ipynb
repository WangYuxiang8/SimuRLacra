# %% [markdown]
# # Plot reinforcement learning episode returns curve

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
root = "~/workspace/SimuRLacra/Pyrado/data/temp/cth/ppo_fnn/2022-07-30_19-18-54/"

# %%
returns = pd.read_csv(root+"returns.csv", encoding='utf-8')
eval_returns = pd.read_csv(root+"eval_returns.csv", encoding='utf-8')
returns.head()
# Out:
#       Wall time  Step       Value
# 0  1.659180e+09     0 -391.901703
# 1  1.659180e+09     1 -388.330200
# 2  1.659180e+09     2 -408.147888
# 3  1.659180e+09     3 -392.706085
# 4  1.659180e+09     4 -364.715088

# %%
plt.plot(returns["Step"], returns["Value"], color="blue")
plt.plot(eval_returns["Step"], eval_returns["Value"], color="orange")
plt.show()
